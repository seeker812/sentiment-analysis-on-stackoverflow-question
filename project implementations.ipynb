# %%
# all of the imports
import pandas as pd
import numpy as np
import pickle 
import patsy
import matplotlib.pyplot as plt
import seaborn as sns


from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split
# %matplotlib inline
from sklearn import preprocessing as pp
import warnings
warnings.filterwarnings('ignore')

# %%
from bs4 import BeautifulSoup


import os
import re
import html as ihtml

# %%
import nltk
import itertools
from nltk.probability import FreqDist
nltk.download('stopwords')
stopset = set(nltk.corpus.stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\SUMIT
# [nltk_data]     PAL\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Importing StackOverflow Data

# %%
questions = pd.read_csv('Questions.csv',encoding='latin1')

# %%
questions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607282 entries, 0 to 607281
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Id            607282 non-null  int64
#  1   OwnerUserId   601070 non-null  float64
#  2   CreationDate  607282 non-null  object
#  3   Score         607282 non-null  int64
#  4   Title         607282 non-null  object
#  5   Body          607282 non-null  object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 27.8+ MB

# %%
questions.head()
# Out:
#     Id  OwnerUserId          CreationDate  Score  \
# 0  469        147.0  2008-08-02T15:11:16Z     21
# 1  502        147.0  2008-08-02T17:01:58Z     27
# 2  535        154.0  2008-08-02T18:43:54Z     40
# 3  594        116.0  2008-08-03T01:15:08Z     25
# 4  683        199.0  2008-08-03T13:19:16Z     28
#
#                                                Title  \
# 0  How can I find the full path to a font from it...
# 1            Get a preview JPEG of a PDF on Windows?
# 2  Continuous Integration System for a Python Cod...
# 3     cx_Oracle: How do I iterate over a result set?
# 4  Using 'in' to match an attribute of Python obj...
#
#                                                 Body
# 0  <p>I am using the Photoshop's javascript API t...
# 1  <p>I have a cross-platform (Python) applicatio...
# 2  <p>I'm starting work on a hobby project with a...
# 3  <p>There are several ways to iterate over a re...
# 4  <p>I don't remember whether I was dreaming or ...

# %% [markdown]
# # Data Processing

# %%
questions['Body'][0]
# Out:
# "<p>I am using the Photoshop's javascript API to find the fonts in a given PSD.</p>\n\n<p>Given a font name returned by the API, I want to find the actual physical font file that that font name corresponds to on the disc.</p>\n\n<p>This is all happening in a python program running on OSX so I guess I'm looking for one of:</p>\n\n<ul>\n<li>Some Photoshop javascript</li>\n<li>A Python function</li>\n<li>An OSX API that I can call from python</li>\n</ul>\n"

# %% [markdown]
# ### 1 Removing html tags from questions

# %%
def clean_text(text):
    text = BeautifulSoup(ihtml.unescape(text), "lxml").text
    text = re.sub(r"http[s]?://\S+", "", text)
    text = re.sub(r"\s+", " ", text)
    return text

# %%
clean_text(questions['Body'][0])
# Out:
# "I am using the Photoshop's javascript API to find the fonts in a given PSD. Given a font name returned by the API, I want to find the actual physical font file that that font name corresponds to on the disc. This is all happening in a python program running on OSX so I guess I'm looking for one of: Some Photoshop javascript A Python function An OSX API that I can call from python "

# %%
questions['Body'] = questions['Body'].apply(clean_text)

# %%
questions.head()
# Out:
#     Id  OwnerUserId          CreationDate  Score  \
# 0  469        147.0  2008-08-02T15:11:16Z     21
# 1  502        147.0  2008-08-02T17:01:58Z     27
# 2  535        154.0  2008-08-02T18:43:54Z     40
# 3  594        116.0  2008-08-03T01:15:08Z     25
# 4  683        199.0  2008-08-03T13:19:16Z     28
#
#                                                Title  \
# 0  How can I find the full path to a font from it...
# 1            Get a preview JPEG of a PDF on Windows?
# 2  Continuous Integration System for a Python Cod...
# 3     cx_Oracle: How do I iterate over a result set?
# 4  Using 'in' to match an attribute of Python obj...
#
#                                                 Body
# 0  I am using the Photoshop's javascript API to f...
# 1  I have a cross-platform (Python) application w...
# 2  I'm starting work on a hobby project with a py...
# 3  There are several ways to iterate over a resul...
# 4  I don't remember whether I was dreaming or not...

# %%
tags = pd.read_csv('Tags.csv')

# %%
tags.head()
# Out:
#     Id        Tag
# 0  469     python
# 1  469        osx
# 2  469      fonts
# 3  469  photoshop
# 4  502     python

# %% [markdown]
# ### 2 Converting all questions to lowercase

# %%
questions['Body Lower'] = questions['Body'].apply(lambda text: text.lower())

# %%
questions['Body Lower'][0]
# Out:
# "i am using the photoshop's javascript api to find the fonts in a given psd. given a font name returned by the api, i want to find the actual physical font file that that font name corresponds to on the disc. this is all happening in a python program running on osx so i guess i'm looking for one of: some photoshop javascript a python function an osx api that i can call from python "

# %% [markdown]
# ### 3 Removing puctuation in questions

# %%
import string

# %%
print(string.punctuation)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
def remove_punctuation(text):
    cleaned_text = text.translate(str.maketrans('','',string.punctuation));
    return cleaned_text

# %%
questions['Cleaned Body'] = questions['Body Lower'].apply(remove_punctuation);

# %%
questions.head()
# Out:
#     Id  OwnerUserId          CreationDate  Score  \
# 0  469        147.0  2008-08-02T15:11:16Z     21
# 1  502        147.0  2008-08-02T17:01:58Z     27
# 2  535        154.0  2008-08-02T18:43:54Z     40
# 3  594        116.0  2008-08-03T01:15:08Z     25
# 4  683        199.0  2008-08-03T13:19:16Z     28
#
#                                                Title  \
# 0  How can I find the full path to a font from it...
# 1            Get a preview JPEG of a PDF on Windows?
# 2  Continuous Integration System for a Python Cod...
# 3     cx_Oracle: How do I iterate over a result set?
# 4  Using 'in' to match an attribute of Python obj...
#
#                                                 Body  \
# 0  I am using the Photoshop's javascript API to f...
# 1  I have a cross-platform (Python) application w...
# 2  I'm starting work on a hobby project with a py...
# 3  There are several ways to iterate over a resul...
# 4  I don't remember whether I was dreaming or not...
#
#                                           Body Lower  \
# 0  i am using the photoshop's javascript api to f...
# 1  i have a cross-platform (python) application w...
# 2  i'm starting work on a hobby project with a py...
# 3  there are several ways to iterate over a resul...
# 4  i don't remember whether i was dreaming or not...
#
#                                         Cleaned Body
# 0  i am using the photoshops javascript api to fi...
# 1  i have a crossplatform python application whic...
# 2  im starting work on a hobby project with a pyt...
# 3  there are several ways to iterate over a resul...
# 4  i dont remember whether i was dreaming or not ...

# %% [markdown]
# ### 4 Tokenized questions

# %%
clean_questions = questions[['Id','Cleaned Body']]

# %%
clean_questions['Tokenized'] = clean_questions['Cleaned Body'].apply(lambda text: text.split())

# %%
clean_questions.head()
# Out:
#     Id                                       Cleaned Body  \
# 0  469  i am using the photoshops javascript api to fi...
# 1  502  i have a crossplatform python application whic...
# 2  535  im starting work on a hobby project with a pyt...
# 3  594  there are several ways to iterate over a resul...
# 4  683  i dont remember whether i was dreaming or not ...
#
#                                            Tokenized
# 0  [i, am, using, the, photoshops, javascript, ap...
# 1  [i, have, a, crossplatform, python, applicatio...
# 2  [im, starting, work, on, a, hobby, project, wi...
# 3  [there, are, several, ways, to, iterate, over,...
# 4  [i, dont, remember, whether, i, was, dreaming,...

# %% [markdown]
# ### 5 Removing stop words

# %%
stop_words = ["i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself",
              "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself",
              "they", "them", "their", "theirs", "themselves", "what", "which", "who", "whom", "this", "that", "these",
              "those", "am", "is", "are", "was", "were", "be", "been", "being", "have", "has", "had", "having", "do",
              "does", "did", "doing", "a", "an", "the", "and", "but", "if", "or", "because", "as", "until", "while",
              "of", "at", "by", "for", "with", "about", "against", "between", "into", "through", "during", "before",
              "after", "above", "below", "to", "from", "up", "down", "in", "out", "on", "off", "over", "under", "again",
              "further", "then", "once", "here", "there", "when", "where", "why", "how", "all", "any", "both", "each",
              "few", "more", "most", "other", "some", "such", "no", "nor", "not", "only", "own", "same", "so", "than",
              "too", "very", "s", "t", "can", "will", "just", "don", "should", "now"]

# %%
def remove_stopped(tokenized):
    final_words =[]
    for word in tokenized:
        if word not in stop_words:
            final_words.append(word)
    return final_words

# %%
clean_questions['remove_stop'] = clean_questions['Tokenized'].apply(remove_stopped)

# %%
clean_questions.head()
# Out:
#     Id                                       Cleaned Body  \
# 0  469  i am using the photoshops javascript api to fi...
# 1  502  i have a crossplatform python application whic...
# 2  535  im starting work on a hobby project with a pyt...
# 3  594  there are several ways to iterate over a resul...
# 4  683  i dont remember whether i was dreaming or not ...
#
#                                            Tokenized  \
# 0  [i, am, using, the, photoshops, javascript, ap...
# 1  [i, have, a, crossplatform, python, applicatio...
# 2  [im, starting, work, on, a, hobby, project, wi...
# 3  [there, are, several, ways, to, iterate, over,...
# 4  [i, dont, remember, whether, i, was, dreaming,...
#
#                                          remove_stop
# 0  [using, photoshops, javascript, api, find, fon...
# 1  [crossplatform, python, application, needs, ge...
# 2  [im, starting, work, hobby, project, python, c...
# 3    [several, ways, iterate, result, set, tradeoff]
# 4  [dont, remember, whether, dreaming, seem, reca...

# %%
emotions_dict = {}
with open('emotions.txt','r') as file:
    for line in file:
        clear_line = line.replace('\n','').replace(',','').replace("'",'')
        word, emotion = clear_line.split(':')
        print("Word : {0} Emotion : {1}".format(word,emotion))
        emotions_dict[word] = emotion
# Out:
# Word :  victimized Emotion :  cheated
# Word :  accused Emotion :  cheated
# Word :  acquitted Emotion :  singled out
# Word :  adorable Emotion :  loved
# Word :  adored Emotion :  loved
# Word :  affected Emotion :  attracted
# Word :  afflicted Emotion :  sad
# Word :  aghast Emotion :  fearful
# Word :  agog Emotion :  attracted
# Word :  agonized Emotion :  sad
# Word :  alarmed Emotion :  fearful
# Word :  amused Emotion :  happy
# Word :  angry Emotion :  angry
# Word :  anguished Emotion :  sad
# Word :  animated Emotion :  happy
# Word :  annoyed Emotion :  angry
# Word :  anxious Emotion :  attracted
# Word :  apathetic Emotion :  bored
# Word :  appalled Emotion :  angry
# Word :  appeased Emotion :  singled out
# Word :  appreciated Emotion :  esteemed
# Word :  apprehensive Emotion :  fearful
# Word :  approved of Emotion :  loved
# Word :  ardent Emotion :  lustful
# Word :  aroused Emotion :  lustful
# Word :  attached Emotion :  attached
# Word :  attracted Emotion :  attracted
# Word :  autonomous Emotion :  independent
# Word :  awed Emotion :  fearful
# Word :  awkward Emotion :  embarrassed
# Word :  beaten down Emotion :  powerless
# Word :  beatific Emotion :  happy
# Word :  belonging Emotion :  attached
# Word :  bereaved Emotion :  sad
# Word :  betrayed Emotion :  cheated
# Word :  bewildered Emotion :  surprise
# Word :  bitter Emotion :  angry
# Word :  blissful Emotion :  happy
# Word :  blithe Emotion :  happy
# Word :  blocked Emotion :  powerless
# Word :  blue Emotion :  sad
# Word :  boiling Emotion :  angry
# Word :  bold Emotion :  fearless
# Word :  bored Emotion :  bored
# Word :  brave Emotion :  fearless
# Word :  bright Emotion :  happy
# Word :  brisk Emotion :  happy
# Word :  calm Emotion :  safe
# Word :  capable Emotion :  adequate
# Word :  captivated Emotion :  attached
# Word :  careless Emotion :  powerless
# Word :  categorized Emotion :  singled out
# Word :  cautious Emotion :  fearful
# Word :  certain Emotion :  fearless
# Word :  chagrined Emotion :  belittled
# Word :  challenged Emotion :  attracted
# Word :  chastised Emotion :  hated
# Word :  cheated Emotion :  cheated
# Word :  cheerful Emotion :  happy
# Word :  cheerless Emotion :  sad
# Word :  cheery Emotion :  happy
# Word :  cherished Emotion :  attached
# Word :  chicken Emotion :  fearful
# Word :  cocky Emotion :  independent
# Word :  codependent Emotion :  codependent
# Word :  coerced Emotion :  cheated
# Word :  comfortable Emotion :  happy
# Word :  common Emotion :  average
# Word :  competent Emotion :  adequate
# Word :  complacent Emotion :  apathetic
# Word :  composed Emotion :  adequate
# Word :  concerned Emotion :  attracted
# Word :  confident Emotion :  adequate
# Word :  confused Emotion :  surprise
# Word :  connected Emotion :  attached
# Word :  conned Emotion :  cheated
# Word :  consumed Emotion :  obsessed
# Word :  contented Emotion :  happy
# Word :  controlled Emotion :  powerless
# Word :  convivial Emotion :  happy
# Word :  cornered Emotion :  entitled
# Word :  courageous Emotion :  fearless
# Word :  cowardly Emotion :  fearful
# Word :  craving Emotion :  attracted
# Word :  crestfallen Emotion :  sad
# Word :  criticized Emotion :  hated
# Word :  cross Emotion :  angry
# Word :  cross-examined Emotion :  singled out
# Word :  crushed Emotion :  sad
# Word :  curious Emotion :  attracted
# Word :  cut off Emotion :  alone
# Word :  daring Emotion :  fearless
# Word :  dark Emotion :  sad
# Word :  dedicated Emotion :  attracted
# Word :  defeated Emotion :  powerless
# Word :  defenseless Emotion :  fearful
# Word :  degraded Emotion :  belittled
# Word :  dejected Emotion :  sad
# Word :  depressed Emotion :  sad
# Word :  deserted Emotion :  hated
# Word :  desirable Emotion :  loved
# Word :  despondent Emotion :  sad
# Word :  detached Emotion :  alone
# Word :  determined Emotion :  focused
# Word :  diminished Emotion :  belittled
# Word :  disappointed Emotion :  demoralized
# Word :  discarded Emotion :  hated
# Word :  disconsolate Emotion :  sad
# Word :  discontented Emotion :  sad
# Word :  discounted Emotion :  belittled
# Word :  discouraged Emotion :  powerless
# Word :  disgraced Emotion :  belittled
# Word :  disgusted Emotion :  angry
# Word :  disheartened Emotion :  demoralized
# Word :  disillusioned Emotion :  demoralized
# Word :  disjointed Emotion :  derailed
# Word :  dismal Emotion :  sad
# Word :  dismayed Emotion :  fearful
# Word :  disoriented Emotion :  derailed
# Word :  disparaged Emotion :  cheated
# Word :  displeased Emotion :  sad
# Word :  disrespected Emotion :  belittled
# Word :  distressed Emotion :  sad
# Word :  distrustful Emotion :  anxious
# Word :  dolorous Emotion :  sad
# Word :  doubtful Emotion :  fearful
# Word :  down Emotion :  sad
# Word :  downhearted Emotion :  sad
# Word :  dreadful Emotion :  sad
# Word :  dreary Emotion :  sad
# Word :  dubious Emotion :  anxious
# Word :  dull Emotion :  sad
# Word :  duped Emotion :  cheated
# Word :  eager Emotion :  attracted
# Word :  earnest Emotion :  attracted
# Word :  ecstatic Emotion :  happy
# Word :  elated Emotion :  happy
# Word :  embarrassed Emotion :  embarrassed
# Word :  empathetic Emotion :  attached
# Word :  enchanted Emotion :  attracted
# Word :  encouraged Emotion :  adequate
# Word :  engrossed Emotion :  attracted
# Word :  enraged Emotion :  angry
# Word :  enterprising Emotion :  fearless
# Word :  enthusiastic Emotion :  happy
# Word :  entrusted Emotion :  loved
# Word :  esteemed Emotion :  esteemed
# Word :  excited Emotion :  happy
# Word :  excluded Emotion :  alone
# Word :  exempt Emotion :  entitled
# Word :  exhausted hopeless Emotion :  powerless
# Word :  exhilarated Emotion :  happy
# Word :  exploited Emotion :  cheated
# Word :  exposed Emotion :  fearful
# Word :  fabulous Emotion :  ecstatic
# Word :  fainthearted Emotion :  fearful
# Word :  fantastic Emotion :  ecstatic
# Word :  fascinated Emotion :  attracted
# Word :  favored Emotion :  entitled
# Word :  fearful Emotion :  fearful
# Word :  fervent Emotion :  attracted
# Word :  fervid Emotion :  attracted
# Word :  festive Emotion :  happy
# Word :  flat Emotion :  sad
# Word :  focused Emotion :  focused
# Word :  forced Emotion :  powerless
# Word :  forsaken Emotion :  hated
# Word :  framed Emotion :  cheated
# Word :  free Emotion :  free
# Word :  free & easy Emotion :  happy
# Word :  frightened Emotion :  fearful
# Word :  frisky Emotion :  happy
# Word :  frustrated Emotion :  angry
# Word :  full of anticipation Emotion :  attracted
# Word :  full of ennui Emotion :  apathetic
# Word :  fuming Emotion :  angry
# Word :  funereal Emotion :  sad
# Word :  furious Emotion :  angry
# Word :  gallant Emotion :  fearless
# Word :  genial Emotion :  happy
# Word :  glad Emotion :  happy
# Word :  gleeful Emotion :  happy
# Word :  gloomy Emotion :  sad
# Word :  glum Emotion :  sad
# Word :  grief-stricken Emotion :  sad
# Word :  grieved Emotion :  sad
# Word :  guilt Emotion :  sad
# Word :  guilty Emotion :  singled out
# Word :  happy Emotion :  happy
# Word :  hardy Emotion :  fearless
# Word :  heartbroken Emotion :  sad
# Word :  heavyhearted Emotion :  sad
# Word :  hesitant Emotion :  fearful
# Word :  high-spirited Emotion :  happy
# Word :  hilarious Emotion :  happy
# Word :  hopeful Emotion :  attracted
# Word :  horny Emotion :  lustful
# Word :  horrified Emotion :  fearful
# Word :  hot and bothered Emotion :  lustful
# Word :  humiliated Emotion :  sad
# Word :  humorous Emotion :  happy
# Word :  hurt Emotion :  sad
# Word :  hysterical Emotion :  fearful
# Word :  ignored Emotion :  hated
# Word :  ill at ease Emotion :  sad
# Word :  immobilized Emotion :  apathetic
# Word :  immune Emotion :  entitled
# Word :  important Emotion :  happy
# Word :  impotent Emotion :  powerless
# Word :  imprisoned Emotion :  entitled
# Word :  in a huff Emotion :  angry
# Word :  in a stew Emotion :  angry
# Word :  in control Emotion :  adequate
# Word :  in fear Emotion :  fearful
# Word :  in pain Emotion :  sad
# Word :  in the dumps Emotion :  sad
# Word :  in the zone Emotion :  focused
# Word :  incensed Emotion :  angry
# Word :  included Emotion :  attached
# Word :  indecisive Emotion :  anxious
# Word :  independent Emotion :  free
# Word :  indignant Emotion :  angry
# Word :  infatuated Emotion :  lustful
# Word :  inflamed Emotion :  angry
# Word :  injured Emotion :  sad
# Word :  inquisitive Emotion :  attracted
# Word :  insecure Emotion :  codependent
# Word :  insignificant Emotion :  belittled
# Word :  intent Emotion :  attracted
# Word :  interested Emotion :  attracted
# Word :  interrogated Emotion :  singled out
# Word :  intrigued Emotion :  attracted
# Word :  irate Emotion :  angry
# Word :  irresolute Emotion :  fearful
# Word :  irresponsible Emotion :  powerless
# Word :  irritated Emotion :  angry
# Word :  isolated Emotion :  alone
# Word :  jaunty Emotion :  happy
# Word :  jocular Emotion :  happy
# Word :  jolly Emotion :  happy
# Word :  jovial Emotion :  happy
# Word :  joyful Emotion :  happy
# Word :  joyless Emotion :  sad
# Word :  joyous Emotion :  happy
# Word :  jubilant Emotion :  happy
# Word :  justified Emotion :  singled out
# Word :  keen Emotion :  attracted
# Word :  labeled Emotion :  singled out
# Word :  lackadaisical Emotion :  bored
# Word :  lazy Emotion :  apathetic
# Word :  left out Emotion :  hated
# Word :  let down Emotion :  hated
# Word :  lethargic Emotion :  apathetic
# Word :  lied to Emotion :  cheated
# Word :  lighthearted Emotion :  happy
# Word :  liked Emotion :  attached
# Word :  lively Emotion :  happy
# Word :  livid Emotion :  angry
# Word :  lonely Emotion :  alone
# Word :  lonesome Emotion :  alone
# Word :  lost Emotion :  lost
# Word :  loved Emotion :  attached
# Word :  low Emotion :  sad
# Word :  lucky Emotion :  happy
# Word :  lugubrious Emotion :  sad
# Word :  macho Emotion :  independent
# Word :  mad Emotion :  angry
# Word :  melancholy Emotion :  sad
# Word :  menaced Emotion :  fearful
# Word :  merry Emotion :  happy
# Word :  mirthful Emotion :  happy
# Word :  misgiving Emotion :  fearful
# Word :  misunderstood Emotion :  alone
# Word :  moody Emotion :  sad
# Word :  moping Emotion :  sad
# Word :  motivated Emotion :  attracted
# Word :  mournful Emotion :  sad
# Word :  needed Emotion :  attracted
# Word :  needy Emotion :  codependent
# Word :  nervous Emotion :  fearful
# Word :  obligated Emotion :  powerless
# Word :  obsessed Emotion :  obsessed
# Word :  offended Emotion :  angry
# Word :  oppressed Emotion :  sad
# Word :  optionless Emotion :  entitled
# Word :  ordinary Emotion :  average
# Word :  organized Emotion :  adequate
# Word :  out of control Emotion :  powerless
# Word :  out of sorts Emotion :  sad
# Word :  outmaneuvered Emotion :  entitled
# Word :  outraged Emotion :  angry
# Word :  overjoyed Emotion :  happy
# Word :  overlooked Emotion :  hated
# Word :  overwhelmed Emotion :  powerless
# Word :  panicked Emotion :  fearful
# Word :  passionate Emotion :  lustful
# Word :  passive Emotion :  apathetic
# Word :  pathetic Emotion :  sad
# Word :  peaceful Emotion :  safe
# Word :  pensive Emotion :  anxious
# Word :  perplexed Emotion :  anxious
# Word :  phobic Emotion :  fearful
# Word :  playful Emotion :  happy
# Word :  pleased Emotion :  happy
# Word :  powerless Emotion :  powerless
# Word :  pressured Emotion :  burdened
# Word :  privileged Emotion :  entitled
# Word :  proud Emotion :  happy
# Word :  provoked Emotion :  angry
# Word :  punished Emotion :  hated
# Word :  put upon Emotion :  burdened
# Word :  quaking Emotion :  fearful
# Word :  quiescent Emotion :  apathetic
# Word :  rageful Emotion :  angry
# Word :  rapturous Emotion :  happy
# Word :  rated Emotion :  singled out
# Word :  reassured Emotion :  fearless
# Word :  reckless Emotion :  powerless
# Word :  redeemed Emotion :  singled out
# Word :  regretful Emotion :  sad
# Word :  rejected Emotion :  alone
# Word :  released Emotion :  free
# Word :  remorse Emotion :  sad
# Word :  replaced Emotion :  hated
# Word :  repulsed Emotion :  demoralized
# Word :  resentful Emotion :  angry
# Word :  resolute Emotion :  fearless
# Word :  respected Emotion :  esteemed
# Word :  responsible Emotion :  adequate
# Word :  restful Emotion :  fearful
# Word :  revered Emotion :  esteemed
# Word :  rueful Emotion :  sad
# Word :  sad Emotion :  sad
# Word :  satisfied Emotion :  happy
# Word :  saucy Emotion :  happy
# Word :  scared Emotion :  fearful
# Word :  secure Emotion :  fearless
# Word :  self-reliant Emotion :  fearless
# Word :  serene Emotion :  happy
# Word :  shaky Emotion :  fearful
# Word :  shamed Emotion :  sad
# Word :  shocked Emotion :  surprise
# Word :  significant Emotion :  esteemed
# Word :  singled out Emotion :  singled out
# Word :  skeptical Emotion :  anxious
# Word :  snoopy Emotion :  attracted
# Word :  somber Emotion :  sad
# Word :  sparkling Emotion :  happy
# Word :  spirited Emotion :  happy
# Word :  spiritless Emotion :  sad
# Word :  sprightly Emotion :  happy
# Word :  startled Emotion :  surprise
# Word :  stereotyped Emotion :  singled out
# Word :  stifled Emotion :  powerless
# Word :  stout hearted Emotion :  fearless
# Word :  strong Emotion :  independent
# Word :  suffering Emotion :  sad
# Word :  sulky Emotion :  sad
# Word :  sullen Emotion :  angry
# Word :  sunny Emotion :  happy
# Word :  surprised Emotion :  surprise
# Word :  suspicious Emotion :  anxious
# Word :  sympathetic Emotion :  codependent
# Word :  tense Emotion :  anxious
# Word :  terrified Emotion :  fearful
# Word :  terrorized Emotion :  fearful
# Word :  thankful Emotion :  happy
# Word :  threatened Emotion :  fearful
# Word :  thwarted Emotion :  powerless
# Word :  timid Emotion :  fearful
# Word :  timorous Emotion :  fearful
# Word :  torn Emotion :  derailed
# Word :  tortured Emotion :  sad
# Word :  tragic Emotion :  sad
# Word :  tranquil Emotion :  happy
# Word :  transported Emotion :  happy
# Word :  trapped Emotion :  entitled
# Word :  tremulous Emotion :  fearful
# Word :  tricked Emotion :  entitled
# Word :  turned on Emotion :  lustful
# Word :  unapproved of Emotion :  hated
# Word :  unbelieving Emotion :  anxious
# Word :  uncertain Emotion :  anxious
# Word :  unconcerned Emotion :  apathetic
# Word :  understood Emotion :  attached
# Word :  unfocussed Emotion :  lost
# Word :  unlovable Emotion :  hated
# Word :  unloved Emotion :  hated
# Word :  unmotivated Emotion :  apathetic
# Word :  unshackled Emotion :  free
# Word :  unsupported Emotion :  belittled
# Word :  up in arms Emotion :  angry
# Word :  upset Emotion :  fearful
# Word :  validated Emotion :  loved
# Word :  valued Emotion :  esteemed
# Word :  victimized Emotion :  sad
# Word :  violated Emotion :  cheated
# Word :  virulent Emotion :  angry
# Word :  vivacious Emotion :  happy
# Word :  vulnerable Emotion :  powerless
# Word :  wavering Emotion :  anxious
# Word :  weak Emotion :  powerless
# Word :  welcomed Emotion :  loved
# Word :  woebegone Emotion :  sad
# Word :  woeful Emotion :  sad
# Word :  worn down Emotion :  powerless
# Word :  worn out Emotion :  powerless
# Word :  worried Emotion :  fearful
# Word :  worshiped Emotion :  esteemed
# Word :  wrathful Emotion :  angry
# Word :  wronged Emotion :  singled out
# Word :  wrought up Emotion :  angry
# Word :  yearning Emotion :  lustful
# Word :  yellow Emotion :  fearful
# Word :  zealous Emotion :  attracted
# Word :  abandoned Emotion :  hated
# Word :  absolved Emotion :  singled out
# Word :  absorbed Emotion :  attracted
# Word :  abused Emotion :  powerless
# Word :  accepted Emotion :  loved
# Word :  aching Emotion :  sad
# Word :  acrimonious Emotion :  angry
# Word :  addicted Emotion :  codependent
# Word :  adequate Emotion :  adequate
# Word :  admired Emotion :  esteemed
# Word :  affectionate Emotion :  attached
# Word :  affronted Emotion :  singled out
# Word :  afraid Emotion :  fearful
# Word :  airy Emotion :  happy
# Word :  alone Emotion :  alone
# Word :  ambivalent Emotion :  bored
# Word :  apathetic Emotion :  apathetic
# Word :  apprehensive Emotion :  anxious
# Word :  arrogant Emotion :  independent
# Word :  ashamed Emotion :  embarrassed
# Word :  astonished Emotion :  surprise
# Word :  at ease Emotion :  safe
# Word :  attacked Emotion :  fearful
# Word :  audacious Emotion :  fearless
# Word :  autonomous Emotion :  free
# Word :  average Emotion :  average
# Word :  avid Emotion :  attracted
# Word :  baffled Emotion :  lost
# Word :  bashful Emotion :  powerless
# Word :  belittled Emotion :  belittled
# Word :  buoyant Emotion :  happy
# Word :  burdened Emotion :  burdened
# Word :  clouded Emotion :  sad
# Word :  committed Emotion :  focused
# Word :  compassionate Emotion :  attached
# Word :  compelled Emotion :  obsessed
# Word :  dauntless Emotion :  fearless
# Word :  debonair Emotion :  happy
# Word :  deceived Emotion :  entitled
# Word :  delighted Emotion :  ecstatic
# Word :  demoralized Emotion :  demoralized
# Word :  derailed Emotion :  derailed
# Word :  desirous Emotion :  attracted
# Word :  despairing Emotion :  sad
# Word :  devastated Emotion :  angry
# Word :  diffident Emotion :  fearful
# Word :  discredited Emotion :  belittled
# Word :  disheartened Emotion :  sad
# Word :  disinclined Emotion :  demoralized
# Word :  disorganized Emotion :  powerless
# Word :  downcast Emotion :  sad
# Word :  entitled Emotion :  entitled
# Word :  excited Emotion :  adequate
# Word :  exultant Emotion :  happy
# Word :  fidgety Emotion :  fearful
# Word :  frowning Emotion :  sad
# Word :  full of misgiving Emotion :  anxious
# Word :  great Emotion :  happy
# Word :  hapless Emotion :  sad
# Word :  hated Emotion :  hated
# Word :  heroic Emotion :  fearless
# Word :  hostile Emotion :  angry
# Word :  in despair Emotion :  sad
# Word :  indifferent Emotion :  bored
# Word :  infuriated Emotion :  angry
# Word :  insecure Emotion :  fearful
# Word :  inspired Emotion :  happy
# Word :  inspiring Emotion :  attracted
# Word :  judged Emotion :  singled out
# Word :  justified Emotion :  singled out
# Word :  laughting Emotion :  happy
# Word :  loved Emotion :  loved
# Word :  loving Emotion :  attached
# Word :  low Emotion :  sad
# Word :  lustful Emotion :  lustful
# Word :  manipulated Emotion :  cheated
# Word :  mumpish Emotion :  sad
# Word :  nosey Emotion :  attracted
# Word :  numb Emotion :  apathetic
# Word :  obliterated Emotion :  powerless
# Word :  peaceful Emotion :  happy
# Word :  petrified Emotion :  fearful
# Word :  piqued Emotion :  angry
# Word :  piteous Emotion :  sad
# Word :  powerless Emotion :  powerless
# Word :  questioning Emotion :  anxious
# Word :  rejected Emotion :  hated
# Word :  self-satisfied Emotion :  happy
# Word :  set up Emotion :  entitled
# Word :  shut out Emotion :  alone
# Word :  sorrowful Emotion :  sad
# Word :  spirited Emotion :  sad
# Word :  supported Emotion :  esteemed
# Word :  suspicious Emotion :  fearful
# Word :  terrific Emotion :  happy
# Word :  trapped Emotion :  entitled
# Word :  trembling Emotion :  fearful
# Word :  uncomfortable Emotion :  anxious
# Word :  underestimated Emotion :  belittled
# Word :  unhappy Emotion :  sad
# Word :  vindicated Emotion :  singled out
# Word :  worked up Emotion :  angry

# %%
def create_emotions(text):
    emotions_list = []
    for word in emotions_dict:
        if word in text:
            emotions_list.append(emotions_dict[word])
    return emotions_list

# %%
clean_questions['emotions_question'] = clean_questions['remove_stop'].apply(create_emotions)

# %%
clean_questions.to_csv('stack_emotions.csv')

# %%
from collections import Counter

# %%
clean_questions['Count emotion'] = clean_questions['emotions_question'].apply(lambda x:Counter(x))

# %% [markdown]
# # Sentiment Analysis

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
 nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to C:\Users\SUMIT
# [nltk_data]     PAL\AppData\Roaming\nltk_data...
# True

# %%
clean_questions.head()
# Out:
#     Id                                       Cleaned Body  \
# 0  469  i am using the photoshops javascript api to fi...
# 1  502  i have a crossplatform python application whic...
# 2  535  im starting work on a hobby project with a pyt...
# 3  594  there are several ways to iterate over a resul...
# 4  683  i dont remember whether i was dreaming or not ...
#
#                                            Tokenized  \
# 0  [i, am, using, the, photoshops, javascript, ap...
# 1  [i, have, a, crossplatform, python, applicatio...
# 2  [im, starting, work, on, a, hobby, project, wi...
# 3  [there, are, several, ways, to, iterate, over,...
# 4  [i, dont, remember, whether, i, was, dreaming,...
#
#                                          remove_stop emotions_question  \
# 0  [using, photoshops, javascript, api, find, fon...                []
# 1  [crossplatform, python, application, needs, ge...                []
# 2  [im, starting, work, hobby, project, python, c...                []
# 3    [several, ways, iterate, result, set, tradeoff]                []
# 4  [dont, remember, whether, dreaming, seem, reca...                []
#
#   Count emotion
# 0            {}
# 1            {}
# 2            {}
# 3            {}
# 4            {}

# %%
def sentiment_analyse(sentiment_text):
    score = SentimentIntensityAnalyzer().polarity_scores(sentiment_text)
    return score

# %%
clean_questions_stack = clean_questions[['Id','Cleaned Body']]

# %%
clean_questions_stack['score'] = clean_questions_stack['Cleaned Body'].apply(sentiment_analyse)

# %%
clean_questions_stack.head()
# Out:
#     Id                                       Cleaned Body  \
# 0  469  i am using the photoshops javascript api to fi...
# 1  502  i have a crossplatform python application whic...
# 2  535  im starting work on a hobby project with a pyt...
# 3  594  there are several ways to iterate over a resul...
# 4  683  i dont remember whether i was dreaming or not ...
#
#                                                score
# 0  {'neg': 0.0, 'neu': 0.981, 'pos': 0.019, 'comp...
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2  {'neg': 0.072, 'neu': 0.863, 'pos': 0.065, 'co...
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4  {'neg': 0.0, 'neu': 0.928, 'pos': 0.072, 'comp...

# %%
clean_questions_stack.drop(['negative','neutral','positive','compound'],axis=1,inplace=True)

# %%
clean_questions_stack.head()
# Out:
#     Id                                       Cleaned Body  \
# 0  469  i am using the photoshops javascript api to fi...
# 1  502  i have a crossplatform python application whic...
# 2  535  im starting work on a hobby project with a pyt...
# 3  594  there are several ways to iterate over a resul...
# 4  683  i dont remember whether i was dreaming or not ...
#
#                                                score
# 0  {'neg': 0.0, 'neu': 0.981, 'pos': 0.019, 'comp...
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2  {'neg': 0.072, 'neu': 0.863, 'pos': 0.065, 'co...
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4  {'neg': 0.0, 'neu': 0.928, 'pos': 0.072, 'comp...

# %%
clean_questions_stack.to_csv('sentiment_stack.csv')

# %%
clean_questions_stack[['Cleaned Body','score']].head(30)
# Out:
#                                          Cleaned Body  \
# 0   i am using the photoshops javascript api to fi...
# 1   i have a crossplatform python application whic...
# 2   im starting work on a hobby project with a pyt...
# 3   there are several ways to iterate over a resul...
# 4   i dont remember whether i was dreaming or not ...
# 5   django view points to a function which can be ...
# 6   i can get python to work with postgresql but i...
# 7   i havent been able to find an understandable e...
# 8   ive read that it is possible to add a method t...
# 9   how do you express an integer as a binary numb...
# 10  i was just looking through some information ab...
# 11  ive got a menu in python that part was easy im...
# 12  what do i need to look at to see if im on wind...
# 13  in many places 123 and 123 can be used interch...
# 14  i have created a phpscript to update a webserv...
# 15  python works on multiple platforms and can be ...
# 16  what is the best way to go about calling a fun...
# 17  i have a prolite led sign that i like to set u...
# 18  when asked to create system xyz and you ask to...
# 19  i tried to follow a couple of googled up tutor...
# 20  a researcher has created a small simulation in...
# 21  i learned swing back in the day but now ive mo...
# 22  i have a binary file that i have to parse and ...
# 23  when i try to print a unicode string in a wind...
# 24  im downloading an entire directory from a web ...
# 25  basically ive written an api to wwwthetvdbcom ...
# 26  i hope this isnt too obscure… ill ask the news...
# 27  what is the library is there a full implementa...
# 28  what is the best way to retrieve mp3 metadata ...
# 29  im trying to decode the result of the python o...
#
#                                                 score
# 0   {'neg': 0.0, 'neu': 0.981, 'pos': 0.019, 'comp...
# 1   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2   {'neg': 0.072, 'neu': 0.863, 'pos': 0.065, 'co...
# 3   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4   {'neg': 0.0, 'neu': 0.928, 'pos': 0.072, 'comp...
# 5   {'neg': 0.036, 'neu': 0.916, 'pos': 0.049, 'co...
# 6   {'neg': 0.099, 'neu': 0.764, 'pos': 0.137, 'co...
# 7   {'neg': 0.035, 'neu': 0.885, 'pos': 0.081, 'co...
# 8   {'neg': 0.077, 'neu': 0.872, 'pos': 0.051, 'co...
# 9   {'neg': 0.045, 'neu': 0.868, 'pos': 0.087, 'co...
# 10  {'neg': 0.0, 'neu': 0.881, 'pos': 0.119, 'comp...
# 11  {'neg': 0.026, 'neu': 0.881, 'pos': 0.093, 'co...
# 12  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 13  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 14  {'neg': 0.029, 'neu': 0.913, 'pos': 0.058, 'co...
# 15  {'neg': 0.073, 'neu': 0.893, 'pos': 0.034, 'co...
# 16  {'neg': 0.0, 'neu': 0.853, 'pos': 0.147, 'comp...
# 17  {'neg': 0.056, 'neu': 0.914, 'pos': 0.03, 'com...
# 18  {'neg': 0.0, 'neu': 0.938, 'pos': 0.062, 'comp...
# 19  {'neg': 0.119, 'neu': 0.777, 'pos': 0.103, 'co...
# 20  {'neg': 0.013, 'neu': 0.879, 'pos': 0.109, 'co...
# 21  {'neg': 0.039, 'neu': 0.833, 'pos': 0.127, 'co...
# 22  {'neg': 0.0, 'neu': 0.951, 'pos': 0.049, 'comp...
# 23  {'neg': 0.057, 'neu': 0.817, 'pos': 0.125, 'co...
# 24  {'neg': 0.0, 'neu': 0.959, 'pos': 0.041, 'comp...
# 25  {'neg': 0.058, 'neu': 0.841, 'pos': 0.101, 'co...
# 26  {'neg': 0.094, 'neu': 0.803, 'pos': 0.103, 'co...
# 27  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 28  {'neg': 0.064, 'neu': 0.72, 'pos': 0.216, 'com...
# 29  {'neg': 0.096, 'neu': 0.87, 'pos': 0.035, 'com...
